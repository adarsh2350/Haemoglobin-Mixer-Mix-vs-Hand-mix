# %%
import gspread
from google.oauth2.service_account import Credentials
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# Connecting sheets
SERVICE_ACCOUNT_FILE = 'app/mobilabhemoglobinhandvsmixer-215a0e65c2f2.json'
SCOPES = ["https://www.googleapis.com/auth/spreadsheets", "https://www.googleapis.com/auth/drive"]
credentials = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
gc = gspread.authorize(credentials)
spreadsheet = gc.open('Haemoglobin extracted data')

sheet = spreadsheet.get_worksheet(0)
data = sheet.get_all_values()
df = pd.DataFrame(data[1:], columns=data[0])
test_data_columns = [col for col in df.columns if col.startswith('Test Data')]
df = df[test_data_columns]

# %%
df.shape
# Out:
# (120, 180)

# %%
df.head()
# Out:
#   Test Data 1 Test Data 2 Test Data 3 Test Data 4 Test Data 5 Test Data 6  \
# 0        7329        7267        7229        7197        7162        7123
# 1        7441        7421        7421        7414        7409        7395
# 2        7292        7324        7367        7416        7470        7508
# 3        7656        7639        7616        7607        7607        7594
# 4        7522        7466        7452        7429        7385        7354
#
#   Test Data 7 Test Data 8 Test Data 9 Test Data 10 Test Data 11 Test Data 12  \
# 0        7077        7039        7006         6986         6942         6898
# 1        7375        7351        7335         7333         7343         7340
# 2        7534        7561        7578         7588         7612         7632
# 3        7589        7593        7600         7617         7627         7637
# 4        7328        7303        7283         7273         7265         7241
#
# ...

# %%
slopes = []
intercepts = []

for row in range(120):  
    data = df.loc[row].values
    cur_slope = []
    cur_intercept = []
    for i in range(len(data) - 14):
        x = np.arange(15)
        y = data[i:i+15]
        y = y.astype(np.float64)
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        cur_slope.append(slope)
        cur_intercept.append(intercept)
    slopes.append(cur_slope)
    intercepts.append(cur_intercept)

# %%
slopes[0]
# Out:
# [-33.53928571428571,
#  -30.953571428571426,
#  -28.174999999999994,
#  -25.203571428571426,
#  -21.982142857142854,
#  -18.539285714285715,
#  -15.714285714285712,
#  -13.285714285714285,
#  -11.44642857142857,
#  -9.282142857142857,
#  -6.528571428571428,
#  -4.367857142857143,
#  -2.9821428571428568,
#  -1.2714285714285714,
#  0.3678571428571428,
#  1.707142857142857,
#  3.096428571428571,
#  5.042857142857142,
#  6.314285714285713,
#  7.182142857142856,
#  6.678571428571429,
#  5.010714285714285,
#  4.2,
#  3.514285714285714,
#  2.853571428571428,
#  2.282142857142857,
#  1.7285714285714284,
#  1.0892857142857142,
#  0.1357142857142857,
#  -1.1107142857142858,
#  -1.907142857142857,
#  -1.6107142857142855,
#  -0.9464285714285714,
#  -0.9071428571428571,
#  -1.2142857142857142,
#  -1.5714285714285712,
#  -2.721428571428571,
#  -3.4642857142857144,
#  -4.442857142857143,
#  -2.742857142857143,
#  -1.7357142857142855,
#  -0.3214285714285714,
#  1.0178571428571428,
# ...

# %%
intercepts[0][66]
# Out:
# 6801.183333333333

# %%
avg_slope = []
for i in range(166):
    SLOP = []
    for j in range(120):
        SLOP.append(slopes[j][i])
    avg_slope.append(abs(np.mean(SLOP)))

avg_slope
# Out:
# [9.571071428571429,
#  8.724821428571428,
#  8.10892857142857,
#  7.496488095238094,
#  6.911130952380952,
#  6.395714285714285,
#  5.985625,
#  5.504047619047619,
#  5.094970238095238,
#  4.634851190476189,
#  4.233869047619048,
#  4.023898809523809,
#  3.799136904761904,
#  3.4024107142857143,
#  2.9492261904761903,
#  2.7098511904761904,
#  2.5261607142857145,
#  2.3745535714285713,
#  2.2320833333333336,
#  2.068035714285714,
#  2.033660714285714,
#  2.029315476190476,
#  2.0291964285714283,
#  2.040982142857143,
#  1.8527678571428572,
#  1.7015178571428569,
#  1.7723511904761902,
#  1.8595535714285711,
#  1.8244345238095234,
#  1.7430059523809522,
#  1.7429166666666667,
#  1.762678571428571,
#  1.624970238095238,
#  1.541190476190476,
#  1.4860119047619047,
#  1.48125,
#  1.4897916666666664,
#  1.4799107142857144,
#  1.532142857142857,
#  1.4848511904761905,
#  1.3461309523809524,
#  1.2211011904761904,
#  1.0168452380952382,
#  0.8747023809523807,
#  0.7644345238095239,
# ...

# %%
sp = np.argmin(avg_slope)
print(f'slope: {avg_slope[sp]}')
print(sp+1,'-',sp+15)
# Out:
# slope: 0.000982142857142835
# 65 - 79

# %%
[sublist[sp] for sublist in slopes]
# Out:
# [-3.642857142857143,
#  -1.0214285714285714,
#  0.18214285714285713,
#  -0.6142857142857142,
#  -18.178571428571427,
#  -2.107142857142857,
#  -3.4785714285714286,
#  -0.04642857142857143,
#  -2.3,
#  0.6499999999999999,
#  4.164285714285714,
#  -0.6892857142857143,
#  18.32142857142857,
#  -0.8928571428571429,
#  3.103571428571428,
#  0.7035714285714285,
#  12.007142857142856,
#  0.3071428571428571,
#  -3.3392857142857144,
#  0.18928571428571428,
#  -1.2642857142857142,
#  0.8107142857142856,
#  0.15357142857142855,
#  1.7,
#  4.182142857142857,
#  -2.6999999999999997,
#  -0.932142857142857,
#  -1.8714285714285712,
#  2.65,
#  -1.5535714285714284,
#  -0.45357142857142857,
#  -1.2892857142857141,
#  -0.125,
#  2.2928571428571427,
#  36.1,
#  5.3,
#  -4.364285714285714,
#  -1.5392857142857141,
#  -3.707142857142857,
#  -1.6535714285714285,
#  -0.8321428571428571,
#  0.5428571428571428,
#  0.8178571428571427,
#  -1.7892857142857141,
#  -2.7821428571428566,
#  -0.6035714285714285,
# ...

# %%
row_index = 60
row_data = [int(k) for k in df.loc[row_index].values]

x = np.arange(len(row_data))

slope = avg_slope[sp]
intercept = intercepts[row_index][sp]
line_y = slope * x + intercept

fig, axs = plt.subplots(2, 1, figsize=(20, 12))

# First subplot: Plot of Row Data with the fitted line
axs[0].scatter(range(len(row_data)), row_data, marker='.', label='Row Data')
axs[0].plot(x, line_y, color='red', label=f'Line: y={slope:.6f}x + {intercept:.6f}')
axs[0].set_title(f'Plot of Row {row_index} Values')
axs[0].set_xlabel('Columns')
axs[0].set_ylabel('Values')
axs[0].legend()
axs[0].grid(True)
axs[0].tick_params(axis='x', rotation=90)

# Second subplot: Plot of slopes for the row
axs[1].scatter(range(len(slopes[row_index])), slopes[row_index], marker='.', label='Row Slopes')
axs[1].set_title(f'Plot of Row {row_index} Slopes')
axs[1].set_xlabel('Columns')
axs[1].set_ylabel('Slopes')
axs[1].legend()
axs[1].grid(True)
axs[1].tick_params(axis='x', rotation=90)

plt.tight_layout()

plt.show()
